# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %%
train = pd.read_csv("/content/drive/MyDrive/112_1/MachineLearning/train.csv", index_col=0)
test = pd.read_csv("/content/drive/MyDrive/112_1/MachineLearning/test.csv", index_col=0)

# %%
train0 = train[train["is_claim"] == 0].sample(1000, random_state=42)
train1 = train[train["is_claim"] == 1].sample(500, random_state=42)
train_new = pd.concat([train0, train1], ignore_index=False)
train_new = train_new.sample(frac=1, random_state=42, ignore_index=False)

# %%
def df_split(df, test_size=0.2):
    i = int((1 - test_size) * len(df))
    o = np.random.permutation(len(df))

    x_train, x_test = np.split(np.take(df, o, axis=0), [i])
    return x_train, x_test

# %%
header = list(train_new.columns)
lst = train_new.values.tolist()

# splitting the data set into train and valid
train_df, valid_df = df_split(lst, test_size=0.2)

# %%
'''
Authors: Ashwani Kashyap, Anshul Pardhi
'''

import math

def unique_vals(rows, col):
    """Find the unique values for a column in a dataset."""
    return set([row[col] for row in rows])

#######
# Demo:
# unique_vals(training_data, 0)
# unique_vals(training_data, 1)
#######


def class_counts(rows):
    """Counts the number of each type of example in a dataset."""
    counts = {}  # a dictionary of label -> count.
    for row in rows:
        # in our dataset format, the label is always the last column
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

#######
# Demo:
# class_counts(training_data)
#######




def max_label(dict):
    max_count = 0
    label = ""

    for key, value in dict.items():
        if dict[key] > max_count:
            max_count = dict[key]
            label = key

    return label




def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

#######
# Demo:
# is_numeric(7)
# is_numeric("Red")
#######


class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 0 for Color) and a
    'column value' (e.g., Green). The 'match' method is used to compare
    the feature value in an example to the feature value stored in the
    question. See the demo below.
    """

    def __init__(self, column, value, header):
        self.column = column
        self.value = value
        self.header = header

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            self.header[self.column], condition, str(self.value))


def partition(rows, question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows


def gini(rows):
    """Calculate the Gini Impurity for a list of rows.

    There are a few different ways to do this, I thought this one was
    the most concise. See:
    https://en.wikipedia.org/wiki/Decision_tree_learning#Gini_impurity
    """
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

## TODO: Step 3
def entropy(rows):

    # compute the entropy.
    entries = class_counts(rows)
    avg_entropy = 0
    size = float(len(rows))
    for label in entries:
        prob = entries[label] / size
        avg_entropy = avg_entropy + (prob * math.log(prob, 2))
    return -1*avg_entropy


def information_gain(left, right, current_uncertainty):
    """Information Gain.

    The uncertainty of the starting node, minus the weighted impurity of
    two child nodes.
    """
    p = float(len(left)) / (len(left) + len(right))

    ## TODO: Step 3, Use Entropy in place of Gini
    return current_uncertainty - p * entropy(left) - (1 - p) * entropy(right)

def find_best_split(rows, header):
    """Find the best question to ask by iterating over every feature / value
    and calculating the information gain."""
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = entropy(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value

            question = Question(col, val, header)

            # try splitting the dataset
            true_rows, false_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = information_gain(true_rows, false_rows, current_uncertainty)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain > best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

## TODO: Step 2
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows, id, depth):
        self.predictions = class_counts(rows)
        self.predicted_label = max_label(self.predictions)
        self.id = id
        self.depth = depth

## TODO: Step 1
class Decision_Node:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch,
                 depth,
                 id,
                 rows):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch
        self.depth = depth
        self.id = id
        self.rows = rows


## TODO: Step 3
def build_tree(rows, header, depth=0, id=0):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """
    # depth = 0
    # Try partitioing the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.

    gain, question = find_best_split(rows, header)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(rows, id, depth)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    # nodeLst.append(id)
    true_rows, false_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows, header, depth + 1, 2 * id + 2)

    # Recursively build the false branch.
    false_branch = build_tree(false_rows, header, depth + 1, 2 * id + 1)

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # depending on on the answer.
    return Decision_Node(question, true_branch, false_branch, depth, id, rows)

## TODO: Step 8 - already done for you
def prune_tree(node, prunedList):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node
    # If we reach a pruned node, make that node a leaf node and return. Since it becomes a leaf node, the nodes
    # below it are automatically not considered
    if int(node.id) in prunedList:
        return Leaf(node.rows, node.id, node.depth)

    # Call this function recursively on the true branch
    node.true_branch = prune_tree(node.true_branch, prunedList)

    # Call this function recursively on the false branch
    node.false_branch = prune_tree(node.false_branch, prunedList)

    return node

## TODO: Step 6
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predicted_label

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

## TODO: Step 4
def print_tree(node, spacing=""):
    """World's most elegant tree printing function."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        print(spacing + "Leaf id: " + str(node.id) + " Predictions: " + str(node.predictions) + " Label Class: " + str(node.predicted_label))
        return

    # Print the question at this node
    print(spacing + str(node.question) + " id: " + str(node.id) + " depth: " + str(node.depth))

    # Call this function recursively on the true branch
    print(spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Call this function recursively on the false branch
    print(spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")


def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

## TODO: Step 5
def getLeafNodes(node, leafNodes =[]):

    # Base case
    if isinstance(node, Leaf):
        leafNodes.append(node)
        return

    # Recursive right call for true values
    getLeafNodes(node.true_branch, leafNodes)

    # Recursive left call for false values
    getLeafNodes(node.false_branch, leafNodes)

    return leafNodes


def getInnerNodes(node, innerNodes =[]):

    # Base case
    if isinstance(node, Leaf):
        return

    innerNodes.append(node)

    # Recursive right call for true values
    getInnerNodes(node.true_branch, innerNodes)

    # Recursive left call for false values
    getInnerNodes(node.false_branch, innerNodes)

    return innerNodes

## TODO: Step 6
def computeAccuracy(rows, node):

    count = len(rows)
    if count == 0:
        return 0

    accuracy = 0
    for row in rows:
        # last entry of the column is the actual label
        if row[-1] == classify(row, node):
            accuracy += 1
    return round(accuracy/count, 2)

# %%
# building the tree
t = build_tree(train_df, header)

# get leaf and inner nodes
print("\nLeaf nodes ****************")
leaves = getLeafNodes(t)
for leaf in leaves:
    print("id = " + str(leaf.id) + " depth =" + str(leaf.depth))

print("\nNon-leaf nodes ****************")
innerNodes = getInnerNodes(t)

for inner in innerNodes:
    print("id = " + str(inner.id) + " depth =" + str(inner.depth))

# print tree
beforeAccuracy = maxAccuracy = computeAccuracy(valid_df, t)
print("\nTree before pruning with accuracy: " + str(maxAccuracy*100) + "\n"). #Tree before pruning with accuracy: 67.0
print_tree(t)

# TODO: You have to decide on a pruning strategy
# Pruning strategy
nodeIdToPrune = -1
for node in innerNodes:
    if node.id != 0:
        prune_tree(t, [node.id])
        currentAccuracy = computeAccuracy(valid_df, t)
        print("Pruned node_id: " + str(node.id) + " to achieve accuracy: " + str(currentAccuracy*100) + "%")
        # print("Pruned Tree")
        # print_tree(t)
        if currentAccuracy > maxAccuracy:
            maxAccuracy = currentAccuracy
            nodeIdToPrune = node.id
        t = build_tree(train_df, header)
        if maxAccuracy == 1:
            break

if nodeIdToPrune != -1:
    t = build_tree(train_df, header)
    prune_tree(t, [nodeIdToPrune])
    print("\nFinal node Id to prune (for max accuracy): " + str(nodeIdToPrune))
else:
    t = build_tree(train_df, header)
    print("\nPruning strategy didn't increased accuracy")

print("\n********************************************************************")
print("*********** Final Tree with accuracy: " + str(maxAccuracy*100) + "%  ************")
print("********************************************************************\n")
print_tree(t)

print("\nTree before pruning with accuracy: " + str(beforeAccuracy*100) + "\n")
# Out:
# Leaf nodes ****************
# id = 30 depth =4
# id = 60 depth =5
# id = 120 depth =6
# id = 119 depth =6
# id = 58 depth =5
# id = 116 depth =6
# id = 232 depth =7
# id = 464 depth =8
# id = 928 depth =9
# id = 927 depth =9
# id = 56 depth =5
# id = 112 depth =6
# id = 450 depth =8
# id = 900 depth =9
# id = 1800 depth =10
# id = 3600 depth =11
# id = 14402 depth =13
# id = 14401 depth =13
# id = 14400 depth =13
# id = 28800 depth =14
# id = 230406 depth =17
# id = 460812 depth =18
# id = 921624 depth =19
# id = 1843248 depth =20
# id = 3686496 depth =21
# id = 3686495 depth =21
# id = 230404 depth =17
# id = 460808 depth =18
# id = 1843234 depth =20
# id = 3686468 depth =21
# id = 7372936 depth =22
# id = 7372935 depth =22
# id = 1843232 depth =20
# id = 3686464 depth =21
# id = 7372928 depth =22
# id = 14745856 depth =23
# id = 29491712 depth =24
# id = 58983424 depth =25
# id = 117966848 depth =26
# id = 235933696 depth =27
# id = 235933695 depth =27
# id = 57599 depth =15
# id = 223 depth =7
# id = 5 depth =2
# id = 10 depth =3
# id = 42 depth =5
# id = 41 depth =5
# id = 40 depth =5
# id = 80 depth =6
# id = 322 depth =8
# id = 644 depth =9
# id = 643 depth =9
# id = 320 depth =8
# id = 640 depth =9
# id = 2562 depth =11
# id = 10250 depth =13
# id = 20500 depth =14
# id = 20499 depth =14
# id = 10248 depth =13
# id = 20496 depth =14
# id = 20495 depth =14
# id = 2560 depth =11
# id = 10242 depth =13
# id = 10241 depth =13
# id = 10240 depth =13
# id = 20480 depth =14
# id = 40960 depth =15
# id = 81920 depth =16
# id = 163840 depth =17
# id = 327680 depth =18
# id = 655360 depth =19
# id = 1310720 depth =20
# id = 2621440 depth =21
# id = 5242880 depth =22
# id = 10485760 depth =23
# id = 20971520 depth =24
# id = 41943040 depth =25
# id = 83886080 depth =26
# id = 167772160 depth =27
# id = 335544320 depth =28
# id = 671088640 depth =29
# id = 1342177280 depth =30
# id = 2684354560 depth =31
# id = 5368709120 depth =32
# id = 10737418240 depth =33
# id = 21474836480 depth =34
# id = 42949672960 depth =35
# id = 85899345920 depth =36
# id = 171798691840 depth =37
# id = 343597383680 depth =38
# id = 687194767360 depth =39
# id = 1374389534720 depth =40
# id = 2748779069440 depth =41
# id = 5497558138880 depth =42
# id = 10995116277760 depth =43
# id = 10995116277759 depth =43
# id = 18 depth =4
# id = 36 depth =5
# id = 72 depth =6
# id = 144 depth =7
# id = 143 depth =7
# id = 295147905179352825855 depth =68
# id = 590295810358705651711 depth =69
# id = 1180591620717411303423 depth =70
# id = 2361183241434822606847 depth =71
# id = 4722366482869645213695 depth =72
# id = 9444732965739290427391 depth =73
# id = 18889465931478580854783 depth =74
# id = 37778931862957161709567 depth =75
# id = 75557863725914323419135 depth =76
# id = 151115727451828646838271 depth =77
# id = 302231454903657293676543 depth =78
# id = 604462909807314587353087 depth =79
# id = 1208925819614629174706175 depth =80
# id = 2417851639229258349412351 depth =81
# id = 4835703278458516698824703 depth =82
# id = 9671406556917033397649407 depth =83
# id = 19342813113834066795298815 depth =84
# id = 38685626227668133590597631 depth =85
# id = 77371252455336267181195263 depth =86
# id = 154742504910672534362390527 depth =87
# id = 309485009821345068724781055 depth =88
# id = 618970019642690137449562111 depth =89
# id = 1237940039285380274899124223 depth =90
# id = 2475880078570760549798248447 depth =91
# id = 4951760157141521099596496896 depth =92
# id = 9903520314283042199192993793 depth =93
# id = 19807040628566084398385987587 depth =94
# id = 39614081257132168796771975175 depth =95
# id = 79228162514264337593543950352 depth =96
# id = 158456325028528675187087900706 depth =97
# id = 316912650057057350374175801413 depth =98
# id = 79228162514264337593543950351 depth =96
# id = 158456325028528675187087900703 depth =97
# id = 316912650057057350374175801407 depth =98
# id = 633825300114114700748351602816 depth =99
# id = 1267650600228229401496703205633 depth =100
# id = 633825300114114700748351602815 depth =99
# id = 1267650600228229401496703205631 depth =100
#
# Tree before pruning with accuracy: 67.0
#
# Is age_of_car == 0.0? id: 0 depth: 0
# --> True:
#   Is airbags == 2? id: 2 depth: 1
#   --> True:
#     Is segment == B2? id: 6 depth: 2
#     --> True:
#       Is policy_tenure == 0.467947605774314? id: 14 depth: 3
#       --> True:
#         Leaf id: 30 Predictions: {'1': 1} Label Class: 1
#       --> False:
#         Is policy_tenure == 0.071839619929935? id: 29 depth: 4
#         --> True:
#           Leaf id: 60 Predictions: {'1': 1} Label Class: 1
#         --> False:
#           Is policy_tenure == 0.145898229013691? id: 59 depth: 5
#           --> True:
#             Leaf id: 120 Predictions: {'1': 1} Label Class: 1
#           --> False:
#             Leaf id: 119 Predictions: {'0': 12} Label Class: 0
#     --> False:
#       Is area_cluster == C5? id: 13 depth: 3
#       --> True:
#         Is age_of_policyholder == 0.355769230769231? id: 28 depth: 4
#         --> True:
#           Leaf id: 58 Predictions: {'1': 2} Label Class: 1
#         --> False:
#           Is policy_tenure == 0.375385221771476? id: 57 depth: 5
#           --> True:
#             Leaf id: 116 Predictions: {'1': 1} Label Class: 1
#           --> False:
#             Is policy_tenure == 0.431579864237944? id: 115 depth: 6
#             --> True:
#               Leaf id: 232 Predictions: {'1': 1} Label Class: 1
#             --> False:
#               Is policy_tenure == 0.559511726029901? id: 231 depth: 7
#               --> True:
#                 Leaf id: 464 Predictions: {'1': 1} Label Class: 1
#               --> False:
#                 Is policy_tenure == 0.141458249077412? id: 463 depth: 8
#                 --> True:
#                   Leaf id: 928 Predictions: {'1': 1} Label Class: 1
#                 --> False:
#                   Leaf id: 927 Predictions: {'0': 13} Label Class: 0
#       --> False:
#         Is age_of_policyholder == 0.403846153846154? id: 27 depth: 4
#         --> True:
#           Leaf id: 56 Predictions: {'1': 5} Label Class: 1
#         --> False:
#           Is age_of_policyholder == 0.471153846153846? id: 55 depth: 5
#           --> True:
#             Leaf id: 112 Predictions: {'0': 2} Label Class: 0
#           --> False:
#             Is make == 1? id: 111 depth: 6
#             --> True:
#               Is age_of_policyholder == 0.5? id: 224 depth: 7
#               --> True:
#                 Leaf id: 450 Predictions: {'1': 3} Label Class: 1
#               --> False:
#                 Is age_of_policyholder == 0.567307692307692? id: 449 depth: 8
#                 --> True:
#                   Leaf id: 900 Predictions: {'1': 2} Label Class: 1
#                 --> False:
#                   Is area_cluster == C22? id: 899 depth: 9
#                   --> True:
#                     Leaf id: 1800 Predictions: {'1': 2} Label Class: 1
#                   --> False:
#                     Is area_cluster == C4? id: 1799 depth: 10
#                     --> True:
#                       Leaf id: 3600 Predictions: {'1': 2} Label Class: 1
#                     --> False:
#                       Is age_of_policyholder == 0.346153846153846? id: 3599 depth: 11
#                       --> True:
#                         Is policy_tenure == 0.085594760570247? id: 7200 depth: 12
#                         --> True:
#                           Leaf id: 14402 Predictions: {'0': 1} Label Class: 0
#                         --> False:
#                           Leaf id: 14401 Predictions: {'1': 5} Label Class: 1
#                       --> False:
#                         Is policy_tenure == 0.079521682937665? id: 7199 depth: 12
#                         --> True:
#                           Leaf id: 14400 Predictions: {'0': 1} Label Class: 0
#                         --> False:
#                           Is age_of_policyholder == 0.298076923076923? id: 14399 depth: 13
#                           --> True:
#                             Leaf id: 28800 Predictions: {'1': 2} Label Class: 1
#                           --> False:
#                             Is segment == A? id: 28799 depth: 14
#                             --> True:
#                               Is area_cluster == C3? id: 57600 depth: 15
#                               --> True:
#                                 Is policy_tenure == 0.095638249705086? id: 115202 depth: 16
#                                 --> True:
#                                   Leaf id: 230406 Predictions: {'0': 1} Label Class: 0
#                                 --> False:
#                                   Is policy_tenure == 0.898910032507334? id: 230405 depth: 17
#                                   --> True:
#                                     Leaf id: 460812 Predictions: {'0': 1} Label Class: 0
#                                   --> False:
#                                     Is policy_tenure == 0.238735169255143? id: 460811 depth: 18
#                                     --> True:
#                                       Leaf id: 921624 Predictions: {'0': 1} Label Class: 0
#                                     --> False:
#                                       Is policy_tenure == 0.230512249679345? id: 921623 depth: 19
#                                       --> True:
#                                         Leaf id: 1843248 Predictions: {'0': 1} Label Class: 0
#                                       --> False:
#                                         Is policy_tenure == 0.166808241123442? id: 1843247 depth: 20
#                                         --> True:
#                                           Leaf id: 3686496 Predictions: {'0': 1} Label Class: 0
#                                         --> False:
#                                           Leaf id: 3686495 Predictions: {'1': 11} Label Class: 1
#                               --> False:
#                                 Is age_of_policyholder == 0.336538461538461? id: 115201 depth: 16
#                                 --> True:
#                                   Leaf id: 230404 Predictions: {'0': 2} Label Class: 0
#                                 --> False:
#                                   Is area_cluster == C7? id: 230403 depth: 17
#                                   --> True:
#                                     Leaf id: 460808 Predictions: {'1': 2} Label Class: 1
#                                   --> False:
#                                     Is area_cluster == C10? id: 460807 depth: 18
#                                     --> True:
#                                       Is policy_tenure == 0.173463908124757? id: 921616 depth: 19
#                                       --> True:
#                                         Leaf id: 1843234 Predictions: {'0': 1} Label Class: 0
#                                       --> False:
#                                         Is policy_tenure == 0.075216436585434? id: 1843233 depth: 20
#                                         --> True:
#                                           Leaf id: 3686468 Predictions: {'0': 1} Label Class: 0
#                                         --> False:
#                                           Is policy_tenure == 0.233716423195089? id: 3686467 depth: 21
#                                           --> True:
#                                             Leaf id: 7372936 Predictions: {'0': 1} Label Class: 0
#                                           --> False:
#                                             Leaf id: 7372935 Predictions: {'1': 6} Label Class: 1
#                                     --> False:
#                                       Is policy_tenure == 0.041254951231581? id: 921615 depth: 19
#                                       --> True:
#                                         Leaf id: 1843232 Predictions: {'1': 1} Label Class: 1
#                                       --> False:
#                                         Is policy_tenure == 0.096452455016382? id: 1843231 depth: 20
#                                         --> True:
#                                           Leaf id: 3686464 Predictions: {'1': 1} Label Class: 1
#                                         --> False:
#                                           Is policy_tenure == 0.223786051956113? id: 3686463 depth: 21
#                                           --> True:
#                                             Leaf id: 7372928 Predictions: {'1': 1} Label Class: 1
#                                           --> False:
#                                             Is policy_tenure == 0.557752901900932? id: 7372927 depth: 22
#                                             --> True:
#                                               Leaf id: 14745856 Predictions: {'1': 1} Label Class: 1
#                                             --> False:
#                                               Is policy_tenure == 0.172199426032729? id: 14745855 depth: 23
#                                               --> True:
#                                                 Leaf id: 29491712 Predictions: {'1': 1} Label Class: 1
#                                               --> False:
#                                                 Is policy_tenure == 0.011379705502843? id: 29491711 depth: 24
#                                                 --> True:
#                                                   Leaf id: 58983424 Predictions: {'1': 1} Label Class: 1
#                                                 --> False:
#                                                   Is policy_tenure == 0.789946183801479? id: 58983423 depth: 25
#                                                   --> True:
#                                                     Leaf id: 117966848 Predictions: {'1': 1} Label Class: 1
#                                                   --> False:
#                                                     Is policy_tenure == 0.357367163715603? id: 117966847 depth: 26
#                                                     --> True:
#                                                       Leaf id: 235933696 Predictions: {'1': 1} Label Class: 1
#                                                     --> False:
#                                                       Leaf id: 235933695 Predictions: {'0': 12} Label Class: 0
#                             --> False:
#                               Leaf id: 57599 Predictions: {'0': 3} Label Class: 0
#             --> False:
#               Leaf id: 223 Predictions: {'1': 3} Label Class: 1
#   --> False:
#     Leaf id: 5 Predictions: {'0': 9} Label Class: 0
# --> False:
#   Is segment == A? id: 1 depth: 1
#   --> True:
#     Is area_cluster == C10? id: 4 depth: 2
#     --> True:
#       Leaf id: 10 Predictions: {'0': 17} Label Class: 0
#     --> False:
#       Is age_of_policyholder == 0.471153846153846? id: 9 depth: 3
#       --> True:
#         Is policy_tenure == 0.041410659860322? id: 20 depth: 4
#         --> True:
#           Leaf id: 42 Predictions: {'0': 1} Label Class: 0
#         --> False:
#           Leaf id: 41 Predictions: {'1': 3} Label Class: 1
#       --> False:
#         Is policy_tenure == 0.839707526557703? id: 19 depth: 4
#         --> True:
#           Leaf id: 40 Predictions: {'1': 1} Label Class: 1
#         --> False:
#           Is policy_tenure == 1.20164209056231? id: 39 depth: 5
#           --> True:
#             Leaf id: 80 Predictions: {'1': 1} Label Class: 1
#           --> False:
#             Is age_of_car == 0.02? id: 79 depth: 6
#             --> True:
#               Is policy_tenure == 0.723732405841772? id: 160 depth: 7
#               --> True:
#                 Leaf id: 322 Predictions: {'1': 1} Label Class: 1
#               --> False:
#                 Is policy_tenure == 0.727119592064144? id: 321 depth: 8
#                 --> True:
#                   Leaf id: 644 Predictions: {'1': 1} Label Class: 1
#                 --> False:
#                   Leaf id: 643 Predictions: {'0': 25} Label Class: 0
#             --> False:
#               Is policy_tenure == 1.04031644235222? id: 159 depth: 7
#               --> True:
#                 Leaf id: 320 Predictions: {'1': 1} Label Class: 1
#               --> False:
#                 Is policy_tenure == 0.509809757265138? id: 319 depth: 8
#                 --> True:
#                   Leaf id: 640 Predictions: {'1': 1} Label Class: 1
#                 --> False:
#                   Is make == 2? id: 639 depth: 9
#                   --> True:
#                     Is policy_tenure == 1.12894495733062? id: 1280 depth: 10
#                     --> True:
#                       Leaf id: 2562 Predictions: {'1': 1} Label Class: 1
#                     --> False:
#                       Is area_cluster == C3? id: 2561 depth: 11
#                       --> True:
#                         Is policy_tenure == 0.579195776934158? id: 5124 depth: 12
#                         --> True:
#                           Leaf id: 10250 Predictions: {'0': 1} Label Class: 0
#                         --> False:
#                           Is policy_tenure == 0.802037499780112? id: 10249 depth: 13
#                           --> True:
#                             Leaf id: 20500 Predictions: {'0': 1} Label Class: 0
#                           --> False:
#                             Leaf id: 20499 Predictions: {'1': 2} Label Class: 1
#                       --> False:
#                         Is policy_tenure == 0.076241084805389? id: 5123 depth: 12
#                         --> True:
#                           Leaf id: 10248 Predictions: {'1': 1} Label Class: 1
#                         --> False:
#                           Is policy_tenure == 1.16797224971701? id: 10247 depth: 13
#                           --> True:
#                             Leaf id: 20496 Predictions: {'1': 1} Label Class: 1
#                           --> False:
#                             Leaf id: 20495 Predictions: {'0': 40} Label Class: 0
#                   --> False:
#                     Is policy_tenure == 0.201708913985795? id: 1279 depth: 10
#                     --> True:
#                       Leaf id: 2560 Predictions: {'1': 1} Label Class: 1
#                     --> False:
#                       Is age_of_car == 0.03? id: 2559 depth: 11
#                       --> True:
#                         Is policy_tenure == 1.05550043409795? id: 5120 depth: 12
#                         --> True:
#                           Leaf id: 10242 Predictions: {'1': 1} Label Class: 1
#                         --> False:
#                           Leaf id: 10241 Predictions: {'0': 15} Label Class: 0
#                       --> False:
#                         Is age_of_policyholder == 0.326923076923077? id: 5119 depth: 12
#                         --> True:
#                           Leaf id: 10240 Predictions: {'0': 5} Label Class: 0
#                         --> False:
#                           Is policy_tenure == 1.02978127215044? id: 10239 depth: 13
#                           --> True:
#                             Leaf id: 20480 Predictions: {'1': 1} Label Class: 1
#                           --> False:
#                             Is area_cluster == C13? id: 20479 depth: 14
#                             --> True:
#                               Leaf id: 40960 Predictions: {'0': 5} Label Class: 0
#                             --> False:
#                               Is policy_tenure == 0.87912348361107? id: 40959 depth: 15
#                               --> True:
#                                 Leaf id: 81920 Predictions: {'1': 1} Label Class: 1
#                               --> False:
#                                 Is policy_tenure == 0.965812421943484? id: 81919 depth: 16
#                                 --> True:
#                                   Leaf id: 163840 Predictions: {'1': 1} Label Class: 1
#                                 --> False:
#                                   Is policy_tenure == 0.33342883143226? id: 163839 depth: 17
#                                   --> True:
#                                     Leaf id: 327680 Predictions: {'1': 1} Label Class: 1
#                                   --> False:
#                                     Is policy_tenure == 0.633606227972745? id: 327679 depth: 18
#                                     --> True:
#                                       Leaf id: 655360 Predictions: {'1': 1} Label Class: 1
#                                     --> False:
#                                       Is policy_tenure == 1.18303944200554? id: 655359 depth: 19
#                                       --> True:
#                                         Leaf id: 1310720 Predictions: {'1': 1} Label Class: 1
#                                       --> False:
#                                         Is policy_tenure == 0.624559442106143? id: 1310719 depth: 20
#                                         --> True:
#                                           Leaf id: 2621440 Predictions: {'1': 1} Label Class: 1
#                                         --> False:
#                                           Is policy_tenure == 0.023521584350423? id: 2621439 depth: 21
#                                           --> True:
#                                             Leaf id: 5242880 Predictions: {'1': 1} Label Class: 1
#                                           --> False:
#                                             Is policy_tenure == 1.16645377853469? id: 5242879 depth: 22
#                                             --> True:
#                                               Leaf id: 10485760 Predictions: {'1': 1} Label Class: 1
#                                             --> False:
#                                               Is policy_tenure == 0.508541119854119? id: 10485759 depth: 23
#                                               --> True:
#                                                 Leaf id: 20971520 Predictions: {'1': 1} Label Class: 1
#                                               --> False:
#                                                 Is area_cluster == C9? id: 20971519 depth: 24
#                                                 --> True:
#                                                   Leaf id: 41943040 Predictions: {'0': 9} Label Class: 0
#                                                 --> False:
#                                                   Is policy_tenure == 0.940218403739534? id: 41943039 depth: 25
#                                                   --> True:
#                                                     Leaf id: 83886080 Predictions: {'1': 1} Label Class: 1
#                                                   --> False:
#                                                     Is policy_tenure == 0.964385569886832? id: 83886079 depth: 26
#                                                     --> True:
#                                                       Leaf id: 167772160 Predictions: {'1': 1} Label Class: 1
#                                                     --> False:
#                                                       Is policy_tenure == 0.747396166385589? id: 167772159 depth: 27
#                                                       --> True:
#                                                         Leaf id: 335544320 Predictions: {'1': 1} Label Class: 1
#                                                       --> False:
#                                                         Is policy_tenure == 0.299137760071793? id: 335544319 depth: 28
#                                                         --> True:
#                                                           Leaf id: 671088640 Predictions: {'1': 1} Label Class: 1
#                                                         --> False:
#                                                           Is policy_tenure == 1.03580740060687? id: 671088639 depth: 29
#                                                           --> True:
#                                                             Leaf id: 1342177280 Predictions: {'1': 1} Label Class: 1
#                                                           --> False:
#                                                             Is policy_tenure == 0.89222754272648? id: 1342177279 depth: 30
#                                                             --> True:
#                                                               Leaf id: 2684354560 Predictions: {'1': 1} Label Class: 1
#                                                             --> False:
#                                                               Is policy_tenure == 0.741344543651984? id: 2684354559 depth: 31
#                                                               --> True:
#                                                                 Leaf id: 5368709120 Predictions: {'1': 1} Label Class: 1
#                                                               --> False:
#                                                                 Is policy_tenure == 0.074043583532591? id: 5368709119 depth: 32
#                                                                 --> True:
#                                                                   Leaf id: 10737418240 Predictions: {'1': 1} Label Class: 1
#                                                                 --> False:
#                                                                   Is policy_tenure == 0.202761905005819? id: 10737418239 depth: 33
#                                                                   --> True:
#                                                                     Leaf id: 21474836480 Predictions: {'1': 1} Label Class: 1
#                                                                   --> False:
#                                                                     Is policy_tenure == 1.02875369426759? id: 21474836479 depth: 34
#                                                                     --> True:
#                                                                       Leaf id: 42949672960 Predictions: {'1': 1} Label Class: 1
#                                                                     --> False:
#                                                                       Is policy_tenure == 0.5031620034593? id: 42949672959 depth: 35
#                                                                       --> True:
#                                                                         Leaf id: 85899345920 Predictions: {'1': 1} Label Class: 1
#                                                                       --> False:
#                                                                         Is policy_tenure == 0.307182064993403? id: 85899345919 depth: 36
#                                                                         --> True:
#                                                                           Leaf id: 171798691840 Predictions: {'1': 1} Label Class: 1
#                                                                         --> False:
#                                                                           Is policy_tenure == 0.98488495022392? id: 171798691839 depth: 37
#                                                                           --> True:
#                                                                             Leaf id: 343597383680 Predictions: {'1': 1} Label Class: 1
#                                                                           --> False:
#                                                                             Is policy_tenure == 0.263597031976075? id: 343597383679 depth: 38
#                                                                             --> True:
#                                                                               Leaf id: 687194767360 Predictions: {'1': 1} Label Class: 1
#                                                                             --> False:
#                                                                               Is policy_tenure == 0.113592396744644? id: 687194767359 depth: 39
#                                                                               --> True:
#                                                                                 Leaf id: 1374389534720 Predictions: {'1': 1} Label Class: 1
#                                                                               --> False:
#                                                                                 Is policy_tenure == 0.651697890595438? id: 1374389534719 depth: 40
#                                                                                 --> True:
#                                                                                   Leaf id: 2748779069440 Predictions: {'1': 1} Label Class: 1
#                                                                                 --> False:
#                                                                                   Is policy_tenure == 0.538945645192764? id: 2748779069439 depth: 41
#                                                                                   --> True:
#                                                                                     Leaf id: 5497558138880 Predictions: {'1': 1} Label Class: 1
#                                                                                   --> False:
#                                                                                     Is policy_tenure == 0.61925303768854? id: 5497558138879 depth: 42
#                                                                                     --> True:
#                                                                                       Leaf id: 10995116277760 Predictions: {'1': 1} Label Class: 1
#                                                                                     --> False:
#                                                                                       Leaf id: 10995116277759 Predictions: {'0': 63} Label Class: 0
#   --> False:
#     Is age_of_car == 0.15? id: 3 depth: 2
#     --> True:
#       Is policy_tenure == 0.504739738554736? id: 8 depth: 3
#       --> True:
#         Leaf id: 18 Predictions: {'1': 1} Label Class: 1
#       --> False:
#         Is policy_tenure == 1.19261246886579? id: 17 depth: 4
#         --> True:
#           Leaf id: 36 Predictions: {'1': 1} Label Class: 1
#         --> False:
#           Is policy_tenure == 0.509648450085407? id: 35 depth: 5
#           --> True:
#             Leaf id: 72 Predictions: {'1': 1} Label Class: 1
#           --> False:
# ...
# Pruned node_id: 2417851639229260496895999 to achieve accuracy: 68.0%
# Pruned node_id: 4835703278458520993791999 to achieve accuracy: 68.0%
# Pruned node_id: 9671406556917041987583999 to achieve accuracy: 68.0%
# Pruned node_id: 19342813113834083975167999 to achieve accuracy: 68.0%
# Pruned node_id: 38685626227668167950335999 to achieve accuracy: 68.0%
# Pruned node_id: 77371252455336335900672000 to achieve accuracy: 68.0%
# Pruned node_id: 154742504910672671801344001 to achieve accuracy: 68.0%
# Pruned node_id: 1208925819614629174706175 to achieve accuracy: 67.0%
# Pruned node_id: 2417851639229258349412351 to achieve accuracy: 67.0%
# Pruned node_id: 4835703278458516698824703 to achieve accuracy: 67.0%
# Pruned node_id: 9671406556917033397649407 to achieve accuracy: 67.0%
# Pruned node_id: 19342813113834066795298815 to achieve accuracy: 67.0%
# Pruned node_id: 38685626227668133590597631 to achieve accuracy: 67.0%
# Pruned node_id: 77371252455336267181195263 to achieve accuracy: 67.0%
# Pruned node_id: 154742504910672534362390527 to achieve accuracy: 67.0%
# Pruned node_id: 309485009821345068724781055 to achieve accuracy: 67.0%
# Pruned node_id: 618970019642690137449562111 to achieve accuracy: 67.0%
# Pruned node_id: 1237940039285380274899124223 to achieve accuracy: 67.0%
# Pruned node_id: 2475880078570760549798248447 to achieve accuracy: 67.0%
# Pruned node_id: 4951760157141521099596496896 to achieve accuracy: 67.0%
# Pruned node_id: 9903520314283042199192993793 to achieve accuracy: 67.0%
# Pruned node_id: 19807040628566084398385987587 to achieve accuracy: 67.0%
# Pruned node_id: 39614081257132168796771975175 to achieve accuracy: 67.0%
# Pruned node_id: 79228162514264337593543950352 to achieve accuracy: 67.0%
# Pruned node_id: 158456325028528675187087900706 to achieve accuracy: 67.0%
# Pruned node_id: 316912650057057350374175801413 to achieve accuracy: 67.0%
# Pruned node_id: 79228162514264337593543950351 to achieve accuracy: 67.0%
# Pruned node_id: 158456325028528675187087900703 to achieve accuracy: 67.0%
# Pruned node_id: 316912650057057350374175801407 to achieve accuracy: 67.0%
# Pruned node_id: 633825300114114700748351602816 to achieve accuracy: 67.0%
# Pruned node_id: 1267650600228229401496703205633 to achieve accuracy: 67.0%
# Pruned node_id: 633825300114114700748351602815 to achieve accuracy: 67.0%
# Pruned node_id: 1267650600228229401496703205631 to achieve accuracy: 67.0%
#
# Final node Id to prune (for max accuracy): 1
#
# ********************************************************************
# *********** Final Tree with accuracy: 69.0%  ************
# ********************************************************************
#
# Is age_of_car == 0.0? id: 0 depth: 0
# --> True:
#   Is airbags == 2? id: 2 depth: 1
#   --> True:
#     Is segment == B2? id: 6 depth: 2
#     --> True:
#       Is policy_tenure == 0.467947605774314? id: 14 depth: 3
#       --> True:
#         Leaf id: 30 Predictions: {'1': 1} Label Class: 1
#       --> False:
#         Is policy_tenure == 0.071839619929935? id: 29 depth: 4
#         --> True:
#           Leaf id: 60 Predictions: {'1': 1} Label Class: 1
#         --> False:
#           Is policy_tenure == 0.145898229013691? id: 59 depth: 5
#           --> True:
#             Leaf id: 120 Predictions: {'1': 1} Label Class: 1
#           --> False:
#             Leaf id: 119 Predictions: {'0': 12} Label Class: 0
#     --> False:
#       Is area_cluster == C5? id: 13 depth: 3
#       --> True:
#         Is age_of_policyholder == 0.355769230769231? id: 28 depth: 4
#         --> True:
#           Leaf id: 58 Predictions: {'1': 2} Label Class: 1
#         --> False:
#           Is policy_tenure == 0.375385221771476? id: 57 depth: 5
#           --> True:
#             Leaf id: 116 Predictions: {'1': 1} Label Class: 1
#           --> False:
#             Is policy_tenure == 0.431579864237944? id: 115 depth: 6
#             --> True:
#               Leaf id: 232 Predictions: {'1': 1} Label Class: 1
#             --> False:
#               Is policy_tenure == 0.559511726029901? id: 231 depth: 7
#               --> True:
#                 Leaf id: 464 Predictions: {'1': 1} Label Class: 1
#               --> False:
#                 Is policy_tenure == 0.141458249077412? id: 463 depth: 8
#                 --> True:
#                   Leaf id: 928 Predictions: {'1': 1} Label Class: 1
#                 --> False:
#                   Leaf id: 927 Predictions: {'0': 13} Label Class: 0
#       --> False:
#         Is age_of_policyholder == 0.403846153846154? id: 27 depth: 4
#         --> True:
#           Leaf id: 56 Predictions: {'1': 5} Label Class: 1
#         --> False:
#           Is age_of_policyholder == 0.471153846153846? id: 55 depth: 5
#           --> True:
#             Leaf id: 112 Predictions: {'0': 2} Label Class: 0
#           --> False:
#             Is make == 1? id: 111 depth: 6
#             --> True:
#               Is age_of_policyholder == 0.5? id: 224 depth: 7
#               --> True:
#                 Leaf id: 450 Predictions: {'1': 3} Label Class: 1
#               --> False:
#                 Is age_of_policyholder == 0.567307692307692? id: 449 depth: 8
#                 --> True:
#                   Leaf id: 900 Predictions: {'1': 2} Label Class: 1
#                 --> False:
#                   Is area_cluster == C22? id: 899 depth: 9
#                   --> True:
#                     Leaf id: 1800 Predictions: {'1': 2} Label Class: 1
#                   --> False:
#                     Is area_cluster == C4? id: 1799 depth: 10
#                     --> True:
#                       Leaf id: 3600 Predictions: {'1': 2} Label Class: 1
#                     --> False:
#                       Is age_of_policyholder == 0.346153846153846? id: 3599 depth: 11
#                       --> True:
#                         Is policy_tenure == 0.085594760570247? id: 7200 depth: 12
#                         --> True:
#                           Leaf id: 14402 Predictions: {'0': 1} Label Class: 0
#                         --> False:
#                           Leaf id: 14401 Predictions: {'1': 5} Label Class: 1
#                       --> False:
#                         Is policy_tenure == 0.079521682937665? id: 7199 depth: 12
#                         --> True:
#                           Leaf id: 14400 Predictions: {'0': 1} Label Class: 0
#                         --> False:
#                           Is age_of_policyholder == 0.298076923076923? id: 14399 depth: 13
#                           --> True:
#                             Leaf id: 28800 Predictions: {'1': 2} Label Class: 1
#                           --> False:
#                             Is segment == A? id: 28799 depth: 14
#                             --> True:
#                               Is area_cluster == C3? id: 57600 depth: 15
#                               --> True:
#                                 Is policy_tenure == 0.095638249705086? id: 115202 depth: 16
#                                 --> True:
#                                   Leaf id: 230406 Predictions: {'0': 1} Label Class: 0
#                                 --> False:
#                                   Is policy_tenure == 0.898910032507334? id: 230405 depth: 17
#                                   --> True:
#                                     Leaf id: 460812 Predictions: {'0': 1} Label Class: 0
#                                   --> False:
#                                     Is policy_tenure == 0.238735169255143? id: 460811 depth: 18
#                                     --> True:
#                                       Leaf id: 921624 Predictions: {'0': 1} Label Class: 0
#                                     --> False:
#                                       Is policy_tenure == 0.230512249679345? id: 921623 depth: 19
#                                       --> True:
#                                         Leaf id: 1843248 Predictions: {'0': 1} Label Class: 0
#                                       --> False:
#                                         Is policy_tenure == 0.166808241123442? id: 1843247 depth: 20
#                                         --> True:
#                                           Leaf id: 3686496 Predictions: {'0': 1} Label Class: 0
#                                         --> False:
#                                           Leaf id: 3686495 Predictions: {'1': 11} Label Class: 1
#                               --> False:
#                                 Is age_of_policyholder == 0.336538461538461? id: 115201 depth: 16
#                                 --> True:
#                                   Leaf id: 230404 Predictions: {'0': 2} Label Class: 0
#                                 --> False:
#                                   Is area_cluster == C7? id: 230403 depth: 17
#                                   --> True:
#                                     Leaf id: 460808 Predictions: {'1': 2} Label Class: 1
#                                   --> False:
#                                     Is area_cluster == C10? id: 460807 depth: 18
#                                     --> True:
#                                       Is policy_tenure == 0.173463908124757? id: 921616 depth: 19
#                                       --> True:
#                                         Leaf id: 1843234 Predictions: {'0': 1} Label Class: 0
#                                       --> False:
#                                         Is policy_tenure == 0.075216436585434? id: 1843233 depth: 20
#                                         --> True:
#                                           Leaf id: 3686468 Predictions: {'0': 1} Label Class: 0
#                                         --> False:
#                                           Is policy_tenure == 0.233716423195089? id: 3686467 depth: 21
#                                           --> True:
#                                             Leaf id: 7372936 Predictions: {'0': 1} Label Class: 0
#                                           --> False:
#                                             Leaf id: 7372935 Predictions: {'1': 6} Label Class: 1
#                                     --> False:
#                                       Is policy_tenure == 0.041254951231581? id: 921615 depth: 19
#                                       --> True:
#                                         Leaf id: 1843232 Predictions: {'1': 1} Label Class: 1
#                                       --> False:
#                                         Is policy_tenure == 0.096452455016382? id: 1843231 depth: 20
#                                         --> True:
#                                           Leaf id: 3686464 Predictions: {'1': 1} Label Class: 1
#                                         --> False:
#                                           Is policy_tenure == 0.223786051956113? id: 3686463 depth: 21
#                                           --> True:
#                                             Leaf id: 7372928 Predictions: {'1': 1} Label Class: 1
#                                           --> False:
#                                             Is policy_tenure == 0.557752901900932? id: 7372927 depth: 22
#                                             --> True:
#                                               Leaf id: 14745856 Predictions: {'1': 1} Label Class: 1
#                                             --> False:
#                                               Is policy_tenure == 0.172199426032729? id: 14745855 depth: 23
#                                               --> True:
#                                                 Leaf id: 29491712 Predictions: {'1': 1} Label Class: 1
#                                               --> False:
#                                                 Is policy_tenure == 0.011379705502843? id: 29491711 depth: 24
#                                                 --> True:
#                                                   Leaf id: 58983424 Predictions: {'1': 1} Label Class: 1
#                                                 --> False:
#                                                   Is policy_tenure == 0.789946183801479? id: 58983423 depth: 25
#                                                   --> True:
#                                                     Leaf id: 117966848 Predictions: {'1': 1} Label Class: 1
#                                                   --> False:
#                                                     Is policy_tenure == 0.357367163715603? id: 117966847 depth: 26
#                                                     --> True:
#                                                       Leaf id: 235933696 Predictions: {'1': 1} Label Class: 1
#                                                     --> False:
#                                                       Leaf id: 235933695 Predictions: {'0': 12} Label Class: 0
#                             --> False:
#                               Leaf id: 57599 Predictions: {'0': 3} Label Class: 0
#             --> False:
#               Leaf id: 223 Predictions: {'1': 3} Label Class: 1
#   --> False:
#     Leaf id: 5 Predictions: {'0': 9} Label Class: 0
# --> False:
#   Leaf id: 1 Predictions: {'0': 740, '1': 337} Label Class: 0
#
# Tree before pruning with accuracy: 67.0

# %% [markdown]
# Tree before pruning with accuracy: 67.0
#
# Final Tree with accuracy: 69.0%
